# %% [markdown]
# #01. Importing Libraries

# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# #02 Importing Data

# %%
#define path to main Instacart project folder
InstacartProjectFolder=r'C:\Users\user\Instacart Basket Analysis 02042023'

# %%
#import orders and products data sets
df_ords=pd.read_pickle(os.path.join(InstacartProjectFolder,'02 Data','Prepared Data','orders_products_merged.pkl'))

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# #03 Create data subset

# %%
df_ords_sub = df_ords[:1000000]

# %%
df_ords_sub.shape
# Out:
# (1000000, 16)

# %% [markdown]
# #04 label price values

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df_ords_sub['price_range'] = df_ords_sub.apply(price_label,axis=1)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8796\3898660542.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ords_sub['price_range'] = df_ords_sub.apply(price_label,axis=1)

# %%
df_ords_sub['price_range'].value_counts(dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df_ords_sub['prices'].max()
# Out:
# 14.8

# %% [markdown]
# #05 use loc() function

# %%
df = df_ords[:1000000]

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1844\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[df['prices']>15,'price_range_loc']='High range product'

# %%
df.loc[(df['prices']<=15)&(df['prices']>5),'price_range_loc']='Mid range product'

# %%
df.loc[df['prices']<=5,'price_range_loc']='Low range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid range product    756450
# Low range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #06 apply loc function to entire dataset

# %%
df_ords.loc[df_ords['prices']>15,'price_range_loc']='High range product'

# %%
df_ords.loc[(df_ords['prices']<=15)&(df_ords['prices']>5),'price_range_loc']='Mid range product'

# %%
df_ords.loc[df_ords['prices']<=5,'price_range_loc']='Low range product'

# %%
df_ords['price_range_loc'].value_counts(dropna=False)
# Out:
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# #07 For loops

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
df_ords['order_dow'].value_counts(dropna=False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
result = []

for value in df_ords["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords['busiest_day'] = result

# %%
df_ords['busiest_day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# #08. Task

# %% [markdown]
# #Question 2 - label two busiest and two slowest days in new column

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
result4=[]

for value in df_ords["order_dow"]:
  if value == 0:
    result4.append("Busiest day 1")
  elif value == 1:
    result4.append("Busiest day 2")
  elif value == 4:
    result4.append("Least busy 1")
  elif value == 3:
    result4.append("Least busy 2")
  else:
    result4.append("Regularly busy")

# %%
result4
# Out:
# ['Regularly busy',
#  'Least busy 2',
#  'Least busy 2',
#  'Least busy 1',
#  'Least busy 1',
#  'Regularly busy',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Least busy 1',
#  'Busiest day 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy 1',
#  'Least busy 2',
#  'Least busy 2',
#  'Least busy 2',
#  'Least busy 1',
#  'Least busy 1',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy 2',
#  'Regularly busy',
#  'Least busy 2',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Regularly busy',
#  'Least busy 2',
#  'Least busy 2',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day 2',
#  'Busiest day 2',
#  'Regularly busy',
#  'Busiest day 2',
# ...

# %%
df_ords['busiest_day2'] = result4

# %%
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# #Question #3 - output for question 2
# I had to try this task a few times.  I finally found my error in that I did not create enough values for result in my For Loop.  Anaconda would not append the new results list as a new column until the number of values matched the number of rows in the total data set.

# %% [markdown]
# #Question 4 - create new column identifying busiest times of day

# %%
df_ords['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %%
result_hour=[]

for value in df_ords["order_hour_of_day"]:
  if value == 10:
    result_hour.append("Most Orders")
  elif value == 3:
    result_hour.append("Fewest Orders")
  else:
    result_hour.append("Average Orders")

# %%
result_hour
# Out:
# ['Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Most Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
#  'Average Orders',
#  'Average Orders',
#  'Most Orders',
# ...

# %%
df_ords['busiest_period_of_day'] = result_hour

# %% [markdown]
# #Question 5 = Frequency of new column

# %%
df_ords['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# Average Orders    29591818
# Most Orders        2761760
# Fewest Orders        51281
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# #Question 7 - Export as a pickle file

# %%
df_ords.to_pickle(os.path.join(InstacartProjectFolder, '02 Data','Prepared Data', 'orders_new_variables.pkl'))
